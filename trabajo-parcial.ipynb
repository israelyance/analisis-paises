# %% [markdown]
# # TRABAJO PARCIAL

# %%
# Librerías básicas
import numpy as np
import pandas as pd

# Librerías para gráficos
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Cargar dataset
gdp = pd.read_csv('countryGDP.csv')
fire = pd.read_csv('GlobalFirePower.csv')
happy = pd.read_csv('happy2015.csv')
lang = pd.read_csv('endangeredLang.csv')

# %%
# Para eliminar los 'future warnings'
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. ANALIZANDO DATA

# %% [markdown]
# ### GDP

# %%
gdp.head(5)
# Out:
#            Country Code  Population  GDP per Capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
# Country           201 non-null object
# Code              201 non-null object
# Population        196 non-null float64
# GDP per Capita    176 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
gdp.describe(include='all')
# Out:
#        Country Code    Population  GDP per Capita
# count      201  201  1.960000e+02      176.000000
# unique     201  201           NaN             NaN
# top     Sweden  PLE           NaN             NaN
# freq         1    1           NaN             NaN
# mean       NaN  NaN  3.722825e+07    12882.556131
# std        NaN  NaN  1.399655e+08    17747.141203
# min        NaN  NaN  1.022200e+04      277.068309
# 25%        NaN  NaN  1.638278e+06     1781.096847
# 50%        NaN  NaN  7.450124e+06     5233.583395
# 75%        NaN  NaN  2.557454e+07    15494.683646
# max        NaN  NaN  1.371220e+09   101449.968168

# %%
np.sum(gdp.isnull())
# Out:
# Country            0
# Code               0
# Population         5
# GDP per Capita    25
# dtype: int64

# %% [markdown]
# ### Fire

# %%
fire.head(5)
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
# 4         France  FRA     5          66836154            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
# 4         23750000                 775000                    387635
#
#    Active Personnel  Reserve Personnel       ...        Railway Coverage (km)  \
# 0           1373650             990025       ...                       224792
# 1            798527            2572500       ...                        87157
# 2           2260000            1452500       ...                        86000
# 3           1362500            2844750       ...                        63974
# 4            204000             183635       ...                        29640
#
#    Serivecable Airports  Defense Budget  External Debt  \
# 0                 13513          587800       17910000
# 1                  1218           44600         514800
# 2                   507          161700         983500
# 3                   346           51000         507000
# 4                   464           35000        5360000
#
#    Foreign Exchange / Gold  Purchasing Power Parity  Square Land Area (km)  \
# 0                   117600                 18560000                9826675
# 1                   365500                  3745000               17098242
# 2                  3092000                 21270000                9596961
# 3                   359100                  8721000                3287263
# 4                   138200                  2737000                 643801
#
#    Coastline (km)  Shared Borders (km)  Waterways (km)
# 0           19924                12048           41009
# 1           37653                22408          102000
# 2           14500                22457          110000
# 3            7000                13888           14500
# 4            4853                 4072            8501
#
# [5 rows x 47 columns]

# %%
fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 47 columns):
# Country                      133 non-null object
# ISO3                         133 non-null object
# Rank                         133 non-null int64
# Total Population             133 non-null int64
# Manpower Available           133 non-null int64
# Fit-for-Service              133 non-null int64
# Reaching Military Age        133 non-null int64
# Total Military Personnel     133 non-null int64
# Active Personnel             133 non-null int64
# Reserve Personnel            133 non-null int64
# Total Aircraft Strength      133 non-null int64
# Fighter Aircraft             133 non-null int64
# Attack Aircraft              133 non-null int64
# Transport Aircraft           133 non-null int64
# Trainer Aircraft             133 non-null int64
# Total Helicopter Strength    133 non-null int64
# Attack Helicopters           133 non-null int64
# Combat Tanks                 133 non-null int64
# Armored Fighting Vehicles    133 non-null int64
# Self-Propelled Artillery     133 non-null int64
# Towed Artillery              133 non-null int64
# Rocket Projectors            133 non-null int64
# Total Naval Assets           133 non-null int64
# Aircraft Carriers            133 non-null int64
# Frigates                     133 non-null int64
# Destroyers                   133 non-null int64
# Corvettes                    133 non-null int64
# Submarines                   133 non-null int64
# Patrol Craft                 133 non-null int64
# Mine Warfare Vessels         133 non-null int64
# Production (bbl/dy)          133 non-null int64
# Consumption (bbl/dy)         133 non-null int64
# Proven Reserves (bbl)        133 non-null int64
# Labor Force                  133 non-null int64
# Merchant Marine Strength     133 non-null int64
# Major Ports / Terminals      133 non-null int64
# Roadway Coverage (km)        133 non-null int64
# Railway Coverage (km)        133 non-null int64
# Serivecable Airports         133 non-null int64
# Defense Budget               133 non-null int64
# External Debt                133 non-null int64
# Foreign Exchange / Gold      133 non-null int64
# Purchasing Power Parity      133 non-null int64
# Square Land Area (km)        133 non-null int64
# Coastline (km)               133 non-null object
# Shared Borders (km)          133 non-null int64
# Waterways (km)               133 non-null object
# dtypes: int64(43), object(4)
# memory usage: 48.9+ KB

# %%
fire.describe(include='all')
# Out:
#        Country ISO3       Rank  Total Population  Manpower Available  \
# count      133  133  133.00000      1.330000e+02        1.330000e+02
# unique     133  133        NaN               NaN                 NaN
# top     Sweden  PAN        NaN               NaN                 NaN
# freq         1    1        NaN               NaN                 NaN
# mean       NaN  NaN   67.00000      5.360087e+07        2.552079e+07
# std        NaN  NaN   38.53786      1.653513e+08        8.531597e+07
# min        NaN  NaN    1.00000      5.858240e+05        1.317000e+05
# 25%        NaN  NaN   34.00000      5.927482e+06        2.770000e+06
# 50%        NaN  NaN   67.00000      1.551071e+07        6.000000e+06
# 75%        NaN  NaN  100.00000      3.852326e+07        1.700000e+07
# max        NaN  NaN  133.00000      1.373541e+09        7.500000e+08
#
#         Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# count      1.330000e+02           1.330000e+02              1.330000e+02
# unique              NaN                    NaN                       NaN
# top                 NaN                    NaN                       NaN
# freq                NaN                    NaN                       NaN
# mean       2.054002e+07           8.749346e+05              4.492374e+05
# std        6.943252e+07           2.673808e+06              1.060239e+06
# min        7.710000e+04           3.030000e+03              2.270000e+03
# 25%        2.255000e+06           8.600000e+04              3.000000e+04
# 50%        4.415000e+06           2.800000e+05              1.112500e+05
# 75%        1.400000e+07           6.650000e+05              3.040000e+05
# max        6.190000e+08           2.290000e+07              6.445000e+06
#
#         Active Personnel  Reserve Personnel        ...         \
# count       1.330000e+02       1.330000e+02        ...
# unique               NaN                NaN        ...
# top                  NaN                NaN        ...
# freq                 NaN                NaN        ...
# mean        1.508728e+05       2.983647e+05        ...
# std         2.895450e+05       8.694605e+05        ...
# min         2.170000e+03       0.000000e+00        ...
# 25%         1.590000e+04       6.500000e+03        ...
# 50%         4.500000e+04       3.580500e+04        ...
# 75%         1.620000e+05       1.500000e+05        ...
# max         2.260000e+06       5.500000e+06        ...
#
#         Railway Coverage (km)  Serivecable Airports  Defense Budget  \
# count              133.000000            133.000000      133.000000
# unique                    NaN                   NaN             NaN
# top                       NaN                   NaN             NaN
# freq                      NaN                   NaN             NaN
# mean              8519.669173            300.165414    11553.827068
# std              23560.623849           1234.570679    53323.041329
# min                  0.000000              2.000000       10.000000
# 25%                660.000000             37.000000      220.000000
# 50%               2239.000000             74.000000     1870.000000
# 75%               5083.000000            157.000000     6215.000000
# max             224792.000000          13513.000000   587800.000000
#
#         External Debt  Foreign Exchange / Gold  Purchasing Power Parity  \
# count    1.330000e+02             1.330000e+02             1.330000e+02
# unique            NaN                      NaN                      NaN
# top               NaN                      NaN                      NaN
# freq              NaN                      NaN                      NaN
# mean     5.426727e+05             8.519197e+04             8.845470e+05
# std      1.892270e+06             3.003522e+05             2.615957e+06
# min      5.020000e+02             1.500000e+01             3.206000e+03
# 25%      9.041000e+03             2.956000e+03             5.894000e+04
# 50%      3.726000e+04             1.310000e+04             1.731000e+05
# 75%      1.600000e+05             5.540000e+04             6.094000e+05
# max      1.791000e+07             3.092000e+06             2.127000e+07
#
#         Square Land Area (km)  Coastline (km)  Shared Borders (km)  \
# count            1.330000e+02             133           133.000000
# unique                    NaN             101                  NaN
# top                       NaN      Landlocked                  NaN
# freq                      NaN              28                  NaN
# mean             9.867789e+05             NaN          3782.699248
# std              2.260928e+06             NaN          3807.738880
# min              6.970000e+02             NaN             0.000000
# 25%              8.934200e+04             NaN          1495.000000
# 50%              3.224630e+05             NaN          2612.000000
# 75%              7.993800e+05             NaN          5244.000000
# max              1.709824e+07             NaN         22457.000000
#
#           Waterways (km)
# count                133
# unique                91
# top     Minimum not met.
# freq                  34
# mean                 NaN
# std                  NaN
# min                  NaN
# 25%                  NaN
# 50%                  NaN
# 75%                  NaN
# max                  NaN
#
# [11 rows x 47 columns]

# %%
np.sum(fire.isnull())
# Out:
# Country                      0
# ISO3                         0
# Rank                         0
# Total Population             0
# Manpower Available           0
# Fit-for-Service              0
# Reaching Military Age        0
# Total Military Personnel     0
# Active Personnel             0
# Reserve Personnel            0
# Total Aircraft Strength      0
# Fighter Aircraft             0
# Attack Aircraft              0
# Transport Aircraft           0
# Trainer Aircraft             0
# Total Helicopter Strength    0
# Attack Helicopters           0
# Combat Tanks                 0
# Armored Fighting Vehicles    0
# Self-Propelled Artillery     0
# Towed Artillery              0
# Rocket Projectors            0
# Total Naval Assets           0
# Aircraft Carriers            0
# Frigates                     0
# Destroyers                   0
# Corvettes                    0
# Submarines                   0
# Patrol Craft                 0
# Mine Warfare Vessels         0
# Production (bbl/dy)          0
# Consumption (bbl/dy)         0
# Proven Reserves (bbl)        0
# Labor Force                  0
# Merchant Marine Strength     0
# Major Ports / Terminals      0
# Roadway Coverage (km)        0
# Railway Coverage (km)        0
# Serivecable Airports         0
# Defense Budget               0
# External Debt                0
# Foreign Exchange / Gold      0
# Purchasing Power Parity      0
# Square Land Area (km)        0
# Coastline (km)               0
# Shared Borders (km)          0
# Waterways (km)               0
# dtype: int64

# %% [markdown]
# ### Happy

# %%
happy.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
happy.describe(include='all')
# Out:
#        Country              Region  Happiness Rank  Happiness Score  \
# count      158                 158      158.000000       158.000000
# unique     158                  10             NaN              NaN
# top     Sweden  Sub-Saharan Africa             NaN              NaN
# freq         1                  40             NaN              NaN
# mean       NaN                 NaN       79.493671         5.375734
# std        NaN                 NaN       45.754363         1.145010
# min        NaN                 NaN        1.000000         2.839000
# 25%        NaN                 NaN       40.250000         4.526000
# 50%        NaN                 NaN       79.500000         5.232500
# 75%        NaN                 NaN      118.750000         6.243750
# max        NaN                 NaN      158.000000         7.587000
#
#         Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000                158.000000  158.000000
# unique             NaN                       NaN         NaN
# top                NaN                       NaN         NaN
# freq               NaN                       NaN         NaN
# mean          0.047885                  0.846137    0.991046
# std           0.017146                  0.403121    0.272369
# min           0.018480                  0.000000    0.000000
# 25%           0.037268                  0.545808    0.856823
# 50%           0.043940                  0.910245    1.029510
# 75%           0.052300                  1.158448    1.214405
# max           0.136930                  1.690420    1.402230
#
#         Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                 158.000000  158.000000                     158.000000
# unique                       NaN         NaN                            NaN
# top                          NaN         NaN                            NaN
# freq                         NaN         NaN                            NaN
# mean                    0.630259    0.428615                       0.143422
# std                     0.247078    0.150693                       0.120034
# min                     0.000000    0.000000                       0.000000
# 25%                     0.439185    0.328330                       0.061675
# 50%                     0.696705    0.435515                       0.107220
# 75%                     0.811013    0.549092                       0.180255
# max                     1.025250    0.669730                       0.551910
#
#         Generosity  Dystopia Residual
# count   158.000000         158.000000
# unique         NaN                NaN
# top            NaN                NaN
# freq           NaN                NaN
# mean      0.237296           2.098977
# std       0.126685           0.553550
# min       0.000000           0.328580
# 25%       0.150553           1.759410
# 50%       0.216130           2.095415
# 75%       0.309883           2.462415
# max       0.795880           3.602140

# %%
np.sum(happy.isnull())
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# ### Lang

# %%
lang.head(5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
#    Latitude  Longitude                        Description of the location
# 0   40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1   37.4399    14.5019  Sicily (Sicilia), southern and central Calabri...
# 2   53.4029    10.3601  northern Germany, the north-eastern part of th...
# 3   53.9560    27.5756  Belarus except the Polesian-speaking south-wes...
# 4   45.7215     9.3273  the region of Lombardy (except the southernmos...

# %%
lang.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2722 entries, 0 to 2721
# Data columns (total 9 columns):
# ID                             2722 non-null int64
# Name in English                2722 non-null object
# Countries                      2721 non-null object
# Country codes alpha 3          2721 non-null object
# Degree of endangerment         2722 non-null object
# Number of speakers             2539 non-null float64
# Latitude                       2719 non-null float64
# Longitude                      2719 non-null float64
# Description of the location    1870 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 191.5+ KB

# %%
lang.describe(include='all')
# Out:
#                  ID Name in English                 Countries  \
# count   2722.000000            2722                      2721
# unique          NaN            2715                       252
# top             NaN            Koro  United States of America
# freq            NaN               2                       216
# mean    1362.501102             NaN                       NaN
# std      785.919949             NaN                       NaN
# min        2.000000             NaN                       NaN
# 25%      682.250000             NaN                       NaN
# 50%     1362.500000             NaN                       NaN
# 75%     2042.750000             NaN                       NaN
# max     2724.000000             NaN                       NaN
#
#        Country codes alpha 3 Degree of endangerment  Number of speakers  \
# count                   2721                   2722        2.539000e+03
# unique                   252                      5                 NaN
# top                      USA  Definitely endangered                 NaN
# freq                     216                    680                 NaN
# mean                     NaN                    NaN        5.365890e+04
# std                      NaN                    NaN        3.114620e+05
# min                      NaN                    NaN        0.000000e+00
# 25%                      NaN                    NaN        5.000000e+01
# 50%                      NaN                    NaN        8.000000e+02
# 75%                      NaN                    NaN        6.872000e+03
# max                      NaN                    NaN        7.500000e+06
#
#            Latitude    Longitude Description of the location
# count   2719.000000  2719.000000                        1870
# unique          NaN          NaN                        1578
# top             NaN          NaN                  Irian Jaya
# freq            NaN          NaN                          63
# mean      16.247853    22.266012                         NaN
# std       23.241828    92.611293                         NaN
# min      -55.002800  -174.197800                         NaN
# 25%       -2.705000   -69.180850                         NaN
# 50%       15.658700    30.591400                         NaN
# 75%       34.214050   102.366000                         NaN
# max       77.481500   179.187000                         NaN

# %%
np.sum(lang.isnull())
# Out:
# ID                               0
# Name in English                  0
# Countries                        1
# Country codes alpha 3            1
# Degree of endangerment           0
# Number of speakers             183
# Latitude                         3
# Longitude                        3
# Description of the location    852
# dtype: int64

# %% [markdown]
# ## 2. TRANSFORMANDO DATA

# %% [markdown]
# ### Fire: Transformando valores object

# %%
# Analizando Coastline (km)
fire_coastline = fire['Coastline (km)'].value_counts()
fire_coastline[fire_coastline > 1]
# Out:
# Landlocked    28
# 853            2
# 400            2
# 225            2
# 26             2
# 193            2
# Name: Coastline (km), dtype: int64

# %%
# Asignando un nuevo valor en 'Coastline (km)'
fire.loc[fire['Coastline (km)'] == 'Landlocked', 'Coastline (km)'] = '0'
fire['Coastline (km)'] = fire['Coastline (km)'].astype(int)

# %%
# Analizando Waterways (km)
fire_waterways = fire['Waterways (km)'].value_counts()
fire_waterways[fire_waterways > 1]
# Out:
# Minimum not met.    34
# 1600                 3
# 1200                 3
# 800                  2
# 300                  2
# 600                  2
# 1300                 2
# 2250                 2
# Name: Waterways (km), dtype: int64

# %%
# Asignando un nuevo valor en 'Waterways (km)'
fire.loc[fire['Waterways (km)'] == 'Minimum not met.', 'Waterways (km)'] = '0'
fire['Waterways (km)'] = fire['Waterways (km)'].astype(int)

# %% [markdown]
# ### Crear nueva columna a Happy: 'Code'

# %% [markdown]
# Creamos una lista vacía para guardar los países de Happy que no coincidan con los países de GDP:

# %%
happy_code_missing = []
for i in range(0, happy.shape[0]):
    happy_country = happy.loc[i, 'Country']
    gdp_country = gdp[gdp['Country'] == happy_country]
    if gdp_country.empty:
        happy_code_missing.append([i, happy_country])
    else:
        index = gdp_country.index[0]
        happy.loc[i, 'Code'] = gdp.loc[index, 'Code']
happy_code_missing
# Out:
# [[46, 'South Korea'],
#  [65, 'North Cyprus'],
#  [68, 'Kosovo'],
#  [71, 'Hong Kong'],
#  [82, 'Montenegro'],
#  [90, 'Somaliland region'],
#  [107, 'Palestinian Territories'],
#  [119, 'Congo (Kinshasa)'],
#  [128, 'Myanmar'],
#  [138, 'Congo (Brazzaville)'],
#  [150, 'Ivory Coast']]

# %%
# Asignar valores a los países faltantes
happy.loc[46, 'Code'] = 'KOR' #South Korea
#happy.loc[65, 'Code'] = '' #North Cyprus
happy.loc[68, 'Code'] = 'KOS' #Kosovo
happy.loc[71, 'Code'] = 'HKG' #Hong Kong
happy.loc[82, 'Code'] = 'MNE' #Montenegro
#happy.loc[90, 'Code'] = '' #Somaliland region
happy.loc[107, 'Code'] = 'PLE' #Palestinian Territories
happy.loc[128, 'Code'] = 'MMR' #Myanmar
happy.loc[119, 'Code'] = 'COD' #Congo (Kinshasa)
happy.loc[138, 'Code'] = 'CGO' #Congo (Brazzaville)
happy.loc[150, 'Code'] = 'CIV' #Ivory Coast

# %% [markdown]
# ### Asignar index

# %%
# Colocamos en los dataframes el código COI como index
gdp.index = gdp['Code']
gdp.drop(columns = ['Code'], axis = 1, inplace = True)
fire.index = fire['ISO3']
fire.drop(columns = ['ISO3'], axis = 1, inplace = True)
happy.index = happy['Code']
happy.drop(columns = ['Code'], axis = 1, inplace = True)

# %% [markdown]
# ### Analizando las correlaciones

# %%
# Correlaciones en gdp
gdp_corr = gdp.corr()
gdp_corr
# Out:
#                 Population  GDP per Capita
# Population        1.000000       -0.042539
# GDP per Capita   -0.042539        1.000000

# %%
# Correlaciones en fire
fire_corr = fire.corr()
fire_corr = fire_corr[(fire_corr > 0.75) | (fire_corr < -0.75)]
fire_corr
# Out:
#                            Rank  Total Population  Manpower Available  \
# Rank                        1.0               NaN                 NaN
# Total Population            NaN          1.000000            0.996207
# Manpower Available          NaN          0.996207            1.000000
# Fit-for-Service             NaN          0.995066            0.998243
# Reaching Military Age       NaN          0.989521            0.977965
# Total Military Personnel    NaN               NaN                 NaN
# Active Personnel            NaN          0.832728            0.837768
# Reserve Personnel           NaN               NaN                 NaN
# Total Aircraft Strength     NaN               NaN                 NaN
# Fighter Aircraft            NaN               NaN                 NaN
# Attack Aircraft             NaN               NaN                 NaN
# Transport Aircraft          NaN               NaN                 NaN
# Trainer Aircraft            NaN               NaN                 NaN
# Total Helicopter Strength   NaN               NaN                 NaN
# Attack Helicopters          NaN               NaN                 NaN
# Combat Tanks                NaN               NaN                 NaN
# Armored Fighting Vehicles   NaN               NaN                 NaN
# Self-Propelled Artillery    NaN               NaN                 NaN
# Towed Artillery             NaN               NaN                 NaN
# Rocket Projectors           NaN               NaN                 NaN
# Total Naval Assets          NaN               NaN                 NaN
# Aircraft Carriers           NaN               NaN                 NaN
# Frigates                    NaN               NaN                 NaN
# Destroyers                  NaN               NaN                 NaN
# Corvettes                   NaN               NaN                 NaN
# Submarines                  NaN               NaN                 NaN
# Patrol Craft                NaN               NaN                 NaN
# Mine Warfare Vessels        NaN               NaN                 NaN
# Production (bbl/dy)         NaN               NaN                 NaN
# Consumption (bbl/dy)        NaN               NaN                 NaN
# Proven Reserves (bbl)       NaN               NaN                 NaN
# Labor Force                 NaN          0.982513            0.989829
# Merchant Marine Strength    NaN               NaN                 NaN
# Major Ports / Terminals     NaN               NaN                 NaN
# Roadway Coverage (km)       NaN               NaN                 NaN
# Railway Coverage (km)       NaN               NaN                 NaN
# Serivecable Airports        NaN               NaN                 NaN
# Defense Budget              NaN               NaN                 NaN
# External Debt               NaN               NaN                 NaN
# Foreign Exchange / Gold     NaN               NaN                 NaN
# Purchasing Power Parity     NaN          0.798187            0.803706
# Square Land Area (km)       NaN               NaN                 NaN
# Coastline (km)              NaN               NaN                 NaN
# Shared Borders (km)         NaN               NaN                 NaN
# Waterways (km)              NaN               NaN                 NaN
#
#                            Fit-for-Service  Reaching Military Age  \
# Rank                                   NaN                    NaN
# Total Population                  0.995066               0.989521
# Manpower Available                0.998243               0.977965
# Fit-for-Service                   1.000000               0.975703
# Reaching Military Age             0.975703               1.000000
# Total Military Personnel               NaN                    NaN
# Active Personnel                  0.838404               0.792895
# Reserve Personnel                      NaN                    NaN
# Total Aircraft Strength                NaN                    NaN
# Fighter Aircraft                       NaN                    NaN
# Attack Aircraft                        NaN                    NaN
# Transport Aircraft                     NaN                    NaN
# Trainer Aircraft                       NaN                    NaN
# Total Helicopter Strength              NaN                    NaN
# Attack Helicopters                     NaN                    NaN
# Combat Tanks                           NaN                    NaN
# Armored Fighting Vehicles              NaN                    NaN
# Self-Propelled Artillery               NaN                    NaN
# Towed Artillery                        NaN                    NaN
# Rocket Projectors                      NaN                    NaN
# Total Naval Assets                     NaN                    NaN
# Aircraft Carriers                      NaN                    NaN
# Frigates                               NaN                    NaN
# Destroyers                             NaN                    NaN
# Corvettes                              NaN                    NaN
# Submarines                             NaN                    NaN
# Patrol Craft                           NaN                    NaN
# Mine Warfare Vessels                   NaN                    NaN
# Production (bbl/dy)                    NaN                    NaN
# Consumption (bbl/dy)                   NaN                    NaN
# Proven Reserves (bbl)                  NaN                    NaN
# Labor Force                       0.992808               0.949465
# Merchant Marine Strength               NaN                    NaN
# Major Ports / Terminals                NaN                    NaN
# Roadway Coverage (km)                  NaN                    NaN
# Railway Coverage (km)                  NaN                    NaN
# Serivecable Airports                   NaN                    NaN
# Defense Budget                         NaN                    NaN
# External Debt                          NaN                    NaN
# Foreign Exchange / Gold           0.751969                    NaN
# Purchasing Power Parity           0.807683                    NaN
# Square Land Area (km)                  NaN                    NaN
# Coastline (km)                         NaN                    NaN
# Shared Borders (km)                    NaN                    NaN
# Waterways (km)                         NaN                    NaN
#
#                            Total Military Personnel  Active Personnel  \
# Rank                                            NaN               NaN
# Total Population                                NaN          0.832728
# Manpower Available                              NaN          0.837768
# Fit-for-Service                                 NaN          0.838404
# Reaching Military Age                           NaN          0.792895
# Total Military Personnel                   1.000000               NaN
# Active Personnel                                NaN          1.000000
# Reserve Personnel                          0.974269               NaN
# Total Aircraft Strength                         NaN               NaN
# Fighter Aircraft                                NaN          0.813521
# Attack Aircraft                                 NaN          0.796075
# Transport Aircraft                              NaN               NaN
# Trainer Aircraft                                NaN               NaN
# Total Helicopter Strength                       NaN               NaN
# Attack Helicopters                              NaN               NaN
# Combat Tanks                                    NaN               NaN
# Armored Fighting Vehicles                       NaN               NaN
# Self-Propelled Artillery                        NaN               NaN
# Towed Artillery                            0.832893          0.827123
# Rocket Projectors                               NaN               NaN
# Total Naval Assets                              NaN          0.810323
# Aircraft Carriers                               NaN               NaN
# Frigates                                        NaN          0.759369
# Destroyers                                      NaN               NaN
# Corvettes                                       NaN               NaN
# Submarines                                      NaN          0.810457
# Patrol Craft                                    NaN               NaN
# Mine Warfare Vessels                            NaN               NaN
# Production (bbl/dy)                             NaN               NaN
# Consumption (bbl/dy)                            NaN               NaN
# Proven Reserves (bbl)                           NaN               NaN
# Labor Force                                     NaN          0.842894
# Merchant Marine Strength                        NaN               NaN
# Major Ports / Terminals                         NaN               NaN
# Roadway Coverage (km)                           NaN          0.752750
# Railway Coverage (km)                           NaN               NaN
# Serivecable Airports                            NaN               NaN
# Defense Budget                                  NaN               NaN
# External Debt                                   NaN               NaN
# Foreign Exchange / Gold                         NaN               NaN
# Purchasing Power Parity                         NaN          0.851958
# Square Land Area (km)                           NaN               NaN
# Coastline (km)                                  NaN               NaN
# Shared Borders (km)                             NaN               NaN
# Waterways (km)                                  NaN               NaN
#
#                            Reserve Personnel  Total Aircraft Strength  \
# Rank                                     NaN                      NaN
# Total Population                         NaN                      NaN
# Manpower Available                       NaN                      NaN
# Fit-for-Service                          NaN                      NaN
# Reaching Military Age                    NaN                      NaN
# Total Military Personnel            0.974269                      NaN
# Active Personnel                         NaN                      NaN
# Reserve Personnel                   1.000000                      NaN
# Total Aircraft Strength                  NaN                 1.000000
# Fighter Aircraft                         NaN                 0.943472
# Attack Aircraft                          NaN                 0.945858
# Transport Aircraft                       NaN                 0.989313
# Trainer Aircraft                         NaN                 0.979485
# Total Helicopter Strength                NaN                 0.994162
# Attack Helicopters                       NaN                 0.961413
# Combat Tanks                             NaN                      NaN
# Armored Fighting Vehicles                NaN                 0.861524
# Self-Propelled Artillery                 NaN                      NaN
# Towed Artillery                          NaN                      NaN
# Rocket Projectors                        NaN                      NaN
# Total Naval Assets                       NaN                      NaN
# Aircraft Carriers                        NaN                 0.934610
# Frigates                                 NaN                      NaN
# Destroyers                               NaN                 0.858248
# Corvettes                                NaN                      NaN
# Submarines                               NaN                      NaN
# Patrol Craft                             NaN                      NaN
# Mine Warfare Vessels                     NaN                      NaN
# Production (bbl/dy)                      NaN                      NaN
# Consumption (bbl/dy)                     NaN                 0.929344
# Proven Reserves (bbl)                    NaN                      NaN
# Labor Force                              NaN                      NaN
# Merchant Marine Strength                 NaN                      NaN
# Major Ports / Terminals                  NaN                      NaN
# Roadway Coverage (km)                    NaN                 0.875174
# Railway Coverage (km)                    NaN                 0.927267
# Serivecable Airports                     NaN                 0.896801
# Defense Budget                           NaN                 0.968583
# External Debt                            NaN                 0.803887
# Foreign Exchange / Gold                  NaN                      NaN
# Purchasing Power Parity                  NaN                 0.781732
# Square Land Area (km)                    NaN                      NaN
# Coastline (km)                           NaN                      NaN
# Shared Borders (km)                      NaN                      NaN
# Waterways (km)                           NaN                      NaN
#
#                            Fighter Aircraft       ...        \
# Rank                                    NaN       ...
# Total Population                        NaN       ...
# Manpower Available                      NaN       ...
# Fit-for-Service                         NaN       ...
# Reaching Military Age                   NaN       ...
# Total Military Personnel                NaN       ...
# Active Personnel                   0.813521       ...
# Reserve Personnel                       NaN       ...
# Total Aircraft Strength            0.943472       ...
# Fighter Aircraft                   1.000000       ...
# Attack Aircraft                    0.988066       ...
# Transport Aircraft                 0.897595       ...
# Trainer Aircraft                   0.893392       ...
# Total Helicopter Strength          0.909797       ...
# Attack Helicopters                 0.901990       ...
# Combat Tanks                            NaN       ...
# Armored Fighting Vehicles          0.815083       ...
# Self-Propelled Artillery                NaN       ...
# Towed Artillery                         NaN       ...
# Rocket Projectors                       NaN       ...
# Total Naval Assets                      NaN       ...
# Aircraft Carriers                  0.826343       ...
# Frigates                                NaN       ...
# Destroyers                         0.865215       ...
# Corvettes                               NaN       ...
# Submarines                         0.818616       ...
# Patrol Craft                            NaN       ...
# Mine Warfare Vessels                    NaN       ...
# Production (bbl/dy)                     NaN       ...
# Consumption (bbl/dy)               0.923994       ...
# Proven Reserves (bbl)                   NaN       ...
# Labor Force                             NaN       ...
# Merchant Marine Strength                NaN       ...
# Major Ports / Terminals                 NaN       ...
# Roadway Coverage (km)              0.894615       ...
# Railway Coverage (km)              0.898790       ...
# Serivecable Airports               0.753010       ...
# Defense Budget                     0.902827       ...
# External Debt                           NaN       ...
# Foreign Exchange / Gold                 NaN       ...
# Purchasing Power Parity            0.878771       ...
# Square Land Area (km)                   NaN       ...
# Coastline (km)                          NaN       ...
# Shared Borders (km)                     NaN       ...
# Waterways (km)                          NaN       ...
#
#                            Railway Coverage (km)  Serivecable Airports  \
# Rank                                         NaN                   NaN
# Total Population                             NaN                   NaN
# Manpower Available                           NaN                   NaN
# Fit-for-Service                              NaN                   NaN
# Reaching Military Age                        NaN                   NaN
# Total Military Personnel                     NaN                   NaN
# Active Personnel                             NaN                   NaN
# Reserve Personnel                            NaN                   NaN
# Total Aircraft Strength                 0.927267              0.896801
# Fighter Aircraft                        0.898790              0.753010
# Attack Aircraft                         0.910191              0.755022
# Transport Aircraft                      0.916412              0.927956
# Trainer Aircraft                        0.881068              0.911056
# Total Helicopter Strength               0.912027              0.913198
# Attack Helicopters                      0.895055              0.834183
# Combat Tanks                                 NaN                   NaN
# Armored Fighting Vehicles               0.807208                   NaN
# Self-Propelled Artillery                     NaN                   NaN
# Towed Artillery                              NaN                   NaN
# Rocket Projectors                            NaN                   NaN
# Total Naval Assets                           NaN                   NaN
# Aircraft Carriers                       0.853634              0.874745
# Frigates                                     NaN                   NaN
# Destroyers                              0.828265                   NaN
# Corvettes                                    NaN                   NaN
# Submarines                                   NaN                   NaN
# Patrol Craft                                 NaN                   NaN
# Mine Warfare Vessels                         NaN                   NaN
# Production (bbl/dy)                          NaN                   NaN
# Consumption (bbl/dy)                    0.924057              0.841407
# Proven Reserves (bbl)                        NaN                   NaN
# Labor Force                                  NaN                   NaN
# Merchant Marine Strength                     NaN                   NaN
# Major Ports / Terminals                      NaN                   NaN
# Roadway Coverage (km)                   0.930549              0.798551
# Railway Coverage (km)                   1.000000              0.847715
# Serivecable Airports                    0.847715              1.000000
# Defense Budget                          0.903070              0.911820
# External Debt                           0.766903              0.779058
# Foreign Exchange / Gold                      NaN                   NaN
# Purchasing Power Parity                 0.842218                   NaN
# Square Land Area (km)                        NaN                   NaN
# Coastline (km)                               NaN                   NaN
# Shared Borders (km)                          NaN                   NaN
# Waterways (km)                               NaN                   NaN
#
#                            Defense Budget  External Debt  \
# Rank                                  NaN            NaN
# Total Population                      NaN            NaN
# Manpower Available                    NaN            NaN
# Fit-for-Service                       NaN            NaN
# Reaching Military Age                 NaN            NaN
# Total Military Personnel              NaN            NaN
# Active Personnel                      NaN            NaN
# Reserve Personnel                     NaN            NaN
# Total Aircraft Strength          0.968583       0.803887
# Fighter Aircraft                 0.902827            NaN
# Attack Aircraft                  0.883338            NaN
# Transport Aircraft               0.972650       0.831173
# Trainer Aircraft                 0.962966       0.838321
# Total Helicopter Strength        0.972466       0.825617
# Attack Helicopters               0.904654            NaN
# Combat Tanks                          NaN            NaN
# Armored Fighting Vehicles        0.757345            NaN
# Self-Propelled Artillery              NaN            NaN
# Towed Artillery                       NaN            NaN
# Rocket Projectors                     NaN            NaN
# Total Naval Assets                    NaN            NaN
# Aircraft Carriers                0.935332       0.868888
# Frigates                              NaN            NaN
# Destroyers                       0.854527            NaN
# Corvettes                             NaN            NaN
# Submarines                            NaN            NaN
# Patrol Craft                          NaN            NaN
# Mine Warfare Vessels                  NaN            NaN
# Production (bbl/dy)                   NaN            NaN
# Consumption (bbl/dy)             0.946137       0.769688
# Proven Reserves (bbl)                 NaN            NaN
# Labor Force                           NaN            NaN
# Merchant Marine Strength              NaN            NaN
# Major Ports / Terminals               NaN            NaN
# Roadway Coverage (km)            0.885033            NaN
# Railway Coverage (km)            0.903070       0.766903
# Serivecable Airports             0.911820       0.779058
# Defense Budget                   1.000000       0.836304
# External Debt                    0.836304       1.000000
# Foreign Exchange / Gold               NaN            NaN
# Purchasing Power Parity          0.804295            NaN
# Square Land Area (km)                 NaN            NaN
# Coastline (km)                        NaN            NaN
# Shared Borders (km)                   NaN            NaN
# Waterways (km)                        NaN            NaN
#
#                            Foreign Exchange / Gold  Purchasing Power Parity  \
# Rank                                           NaN                      NaN
# Total Population                               NaN                 0.798187
# Manpower Available                             NaN                 0.803706
# Fit-for-Service                           0.751969                 0.807683
# Reaching Military Age                          NaN                      NaN
# Total Military Personnel                       NaN                      NaN
# Active Personnel                               NaN                 0.851958
# Reserve Personnel                              NaN                      NaN
# Total Aircraft Strength                        NaN                 0.781732
# Fighter Aircraft                               NaN                 0.878771
# Attack Aircraft                                NaN                 0.845794
# Transport Aircraft                             NaN                      NaN
# Trainer Aircraft                               NaN                      NaN
# Total Helicopter Strength                      NaN                      NaN
# Attack Helicopters                             NaN                      NaN
# Combat Tanks                                   NaN                      NaN
# Armored Fighting Vehicles                      NaN                      NaN
# Self-Propelled Artillery                       NaN                      NaN
# Towed Artillery                                NaN                      NaN
# Rocket Projectors                              NaN                      NaN
# Total Naval Assets                             NaN                      NaN
# Aircraft Carriers                              NaN                      NaN
# Frigates                                       NaN                      NaN
# Destroyers                                     NaN                 0.845438
# Corvettes                                      NaN                      NaN
# Submarines                                     NaN                      NaN
# Patrol Craft                                   NaN                      NaN
# Mine Warfare Vessels                           NaN                      NaN
# Production (bbl/dy)                            NaN                      NaN
# Consumption (bbl/dy)                           NaN                 0.921469
# Proven Reserves (bbl)                          NaN                      NaN
# Labor Force                               0.799321                 0.834229
# Merchant Marine Strength                       NaN                      NaN
# Major Ports / Terminals                        NaN                      NaN
# Roadway Coverage (km)                          NaN                 0.929084
# Railway Coverage (km)                          NaN                 0.842218
# Serivecable Airports                           NaN                      NaN
# Defense Budget                                 NaN                 0.804295
# External Debt                                  NaN                      NaN
# Foreign Exchange / Gold                   1.000000                      NaN
# Purchasing Power Parity                        NaN                 1.000000
# Square Land Area (km)                          NaN                      NaN
# Coastline (km)                                 NaN                      NaN
# Shared Borders (km)                            NaN                      NaN
# Waterways (km)                                 NaN                      NaN
#
#                            Square Land Area (km)  Coastline (km)  \
# Rank                                         NaN             NaN
# Total Population                             NaN             NaN
# Manpower Available                           NaN             NaN
# Fit-for-Service                              NaN             NaN
# Reaching Military Age                        NaN             NaN
# Total Military Personnel                     NaN             NaN
# Active Personnel                             NaN             NaN
# Reserve Personnel                            NaN             NaN
# Total Aircraft Strength                      NaN             NaN
# Fighter Aircraft                             NaN             NaN
# Attack Aircraft                              NaN             NaN
# Transport Aircraft                           NaN             NaN
# Trainer Aircraft                             NaN             NaN
# Total Helicopter Strength                    NaN             NaN
# Attack Helicopters                           NaN             NaN
# Combat Tanks                                 NaN             NaN
# Armored Fighting Vehicles                    NaN             NaN
# Self-Propelled Artillery                     NaN             NaN
# Towed Artillery                              NaN             NaN
# Rocket Projectors                            NaN             NaN
# Total Naval Assets                           NaN             NaN
# Aircraft Carriers                            NaN             NaN
# Frigates                                     NaN             NaN
# Destroyers                                   NaN             NaN
# Corvettes                                    NaN             NaN
# Submarines                                   NaN             NaN
# Patrol Craft                                 NaN             NaN
# Mine Warfare Vessels                         NaN             NaN
# Production (bbl/dy)                          NaN             NaN
# Consumption (bbl/dy)                         NaN             NaN
# Proven Reserves (bbl)                        NaN             NaN
# Labor Force                                  NaN             NaN
# Merchant Marine Strength                     NaN             NaN
# Major Ports / Terminals                      NaN             NaN
# Roadway Coverage (km)                        NaN             NaN
# Railway Coverage (km)                        NaN             NaN
# Serivecable Airports                         NaN             NaN
# Defense Budget                               NaN             NaN
# External Debt                                NaN             NaN
# Foreign Exchange / Gold                      NaN             NaN
# Purchasing Power Parity                      NaN             NaN
# Square Land Area (km)                   1.000000             NaN
# Coastline (km)                               NaN             1.0
# Shared Borders (km)                     0.753034             NaN
# Waterways (km)                               NaN             NaN
#
#                            Shared Borders (km)  Waterways (km)
# Rank                                       NaN             NaN
# Total Population                           NaN             NaN
# Manpower Available                         NaN             NaN
# Fit-for-Service                            NaN             NaN
# Reaching Military Age                      NaN             NaN
# Total Military Personnel                   NaN             NaN
# Active Personnel                           NaN             NaN
# Reserve Personnel                          NaN             NaN
# Total Aircraft Strength                    NaN             NaN
# Fighter Aircraft                           NaN             NaN
# Attack Aircraft                            NaN             NaN
# Transport Aircraft                         NaN             NaN
# Trainer Aircraft                           NaN             NaN
# Total Helicopter Strength                  NaN             NaN
# Attack Helicopters                         NaN             NaN
# Combat Tanks                               NaN             NaN
# Armored Fighting Vehicles                  NaN             NaN
# Self-Propelled Artillery                   NaN             NaN
# Towed Artillery                            NaN             NaN
# Rocket Projectors                          NaN             NaN
# Total Naval Assets                         NaN             NaN
# Aircraft Carriers                          NaN             NaN
# Frigates                                   NaN             NaN
# Destroyers                                 NaN             NaN
# Corvettes                                  NaN             NaN
# Submarines                                 NaN             NaN
# Patrol Craft                               NaN             NaN
# Mine Warfare Vessels                       NaN             NaN
# Production (bbl/dy)                        NaN             NaN
# Consumption (bbl/dy)                       NaN             NaN
# Proven Reserves (bbl)                      NaN             NaN
# Labor Force                                NaN             NaN
# Merchant Marine Strength                   NaN             NaN
# Major Ports / Terminals                    NaN             NaN
# Roadway Coverage (km)                      NaN             NaN
# Railway Coverage (km)                      NaN             NaN
# Serivecable Airports                       NaN             NaN
# Defense Budget                             NaN             NaN
# External Debt                              NaN             NaN
# Foreign Exchange / Gold                    NaN             NaN
# Purchasing Power Parity                    NaN             NaN
# Square Land Area (km)                 0.753034             NaN
# Coastline (km)                             NaN             NaN
# Shared Borders (km)                   1.000000             NaN
# Waterways (km)                             NaN             1.0
#
# [45 rows x 45 columns]

# %%
# Correlaciones en happy
happy_corr = happy.corr()
happy_corr = happy_corr[(happy_corr > 0.75) | (happy_corr < -0.75)]
happy_corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                            NaN              NaN
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                                    NaN              NaN
# Health (Life Expectancy)                  NaN              NaN
# Freedom                                   NaN              NaN
# Trust (Government Corruption)             NaN              NaN
# Generosity                                NaN              NaN
# Dystopia Residual                         NaN              NaN
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                            NaN                 -0.785267
# Happiness Score                           NaN                  0.780966
# Standard Error                            1.0                       NaN
# Economy (GDP per Capita)                  NaN                  1.000000
# Family                                    NaN                       NaN
# Health (Life Expectancy)                  NaN                  0.816478
# Freedom                                   NaN                       NaN
# Trust (Government Corruption)             NaN                       NaN
# Generosity                                NaN                       NaN
# Dystopia Residual                         NaN                       NaN
#
#                                Family  Health (Life Expectancy)  Freedom  \
# Happiness Rank                    NaN                       NaN      NaN
# Happiness Score                   NaN                       NaN      NaN
# Standard Error                    NaN                       NaN      NaN
# Economy (GDP per Capita)          NaN                  0.816478      NaN
# Family                            1.0                       NaN      NaN
# Health (Life Expectancy)          NaN                  1.000000      NaN
# Freedom                           NaN                       NaN      1.0
# Trust (Government Corruption)     NaN                       NaN      NaN
# Generosity                        NaN                       NaN      NaN
# Dystopia Residual                 NaN                       NaN      NaN
#
#                                Trust (Government Corruption)  Generosity  \
# Happiness Rank                                           NaN         NaN
# Happiness Score                                          NaN         NaN
# Standard Error                                           NaN         NaN
# Economy (GDP per Capita)                                 NaN         NaN
# Family                                                   NaN         NaN
# Health (Life Expectancy)                                 NaN         NaN
# Freedom                                                  NaN         NaN
# Trust (Government Corruption)                            1.0         NaN
# Generosity                                               NaN         1.0
# Dystopia Residual                                        NaN         NaN
#
#                                Dystopia Residual
# Happiness Rank                               NaN
# Happiness Score                              NaN
# Standard Error                               NaN
# Economy (GDP per Capita)                     NaN
# Family                                       NaN
# Health (Life Expectancy)                     NaN
# Freedom                                      NaN
# Trust (Government Corruption)                NaN
# Generosity                                   NaN
# Dystopia Residual                            1.0

# %% [markdown]
# ### Eliminando data para analizar

# %% [markdown]
# Basado en las correlaciones eliminamos las siguientes variables

# %%
# Eliminando columnas en fire
fire_drop = ['Fit-for-Service', 'Reaching Military Age', 'Active Personnel',
             'Reserve Personnel', 'Labor Force', 'Purchasing Power Parity',
             'Fighter Aircraft', 'Attack Aircraft', 'Transport Aircraft',
             'Trainer Aircraft', 'Total Helicopter Strength', 'Attack Helicopters',
             'Roadway Coverage (km)', 'Railway Coverage (km)', 'Serivecable Airports',
             'Aircraft Carriers', 'Armored Fighting Vehicles', 'Destroyers',
             'Self-Propelled Artillery', 'Rocket Projectors', 'Consumption (bbl/dy)',
             'Corvettes', 'Submarines', 'Towed Artillery',
             'Defense Budget', 'External Debt', 'Patrol Craft',
             'Shared Borders (km)']
fire.drop(columns = fire_drop, axis = 1, inplace = True)

# %%
# Eliminando columnas en happy
happy_drop = ['Happiness Rank', 'Economy (GDP per Capita)']
happy.drop(columns = happy_drop, axis = 1, inplace = True)

# %% [markdown]
# ### Juntando la información

# %% [markdown]
# Primero asignamos nombres diferentes para las columnas 'Country', para poder eliminarlas después más fácilmente.

# %%
# Concatenamos los dataframes:
gdp.columns
gdp.columns = ['Country GDP', 'Population', 'GDP per Capita']
happy.columns
happy.columns = ['Country Happy', 'Region', 'Happiness Score',
                 'Standard Error', 'Family', 'Health (Life Expectancy)',
                 'Freedom', 'Trust (Government Corruption)', 'Generosity',
                 'Dystopia Residual']
data_total = pd.concat([gdp, fire, happy], join = 'inner', axis = 1)
data_total.drop( columns = ['Country', 'Country Happy'], axis = 1, inplace = True)

# %% [markdown]
# ## 3. VISUALIZACIÓN

# %%
# El GDP per Capita por cada Region
sns.set(style='whitegrid')
f, ax = plt.subplots(figsize=(6, 6))
sns.set_color_codes('pastel')
sns.barplot(x = 'GDP per Capita', y = 'Region', data = data_total,
            label = 'GSP', color = "b")
plt.show()

# %% [markdown]
# Se encontró, que de todas las regiones, Norte América, Europa Oeste, Australia y Nueva Zelanda son las 3 que tienen una mejor economía en base a su PBI per cápita.

# %%
# Visualización de las principales variables 
sns.set(style="ticks",color_codes=True)
grafico2 = data_total[['Region','Happiness Score', 'GDP per Capita',
                       'Health (Life Expectancy)', 'Trust (Government Corruption)']]
sns.pairplot(grafico2, hue = 'Region', palette = 'Spectral')
plt.show()

# %%
# 'GDP per Capita' vs 'Happiness Score' por Región 
sns.lmplot(x = 'GDP per Capita', y = "Happiness Score", data = data_total,
           fit_reg = False, hue = 'Region', legend = True, palette = 'Paired')
plt.show()

# %% [markdown]
# Vemos que hay una marcada relación entre el 'GDP per Capita' y el 'Happiness Score', y los países que tienen mejores indicadores en ambos son del oeste de Europa.
